# %% [markdown]
# ```
# ```
#
# ecommerce\_cv\_project/<br>
# │
# ├── app.js                           # Entry point for Express app<br>
# ├── package.json                     # Project metadata & dependencies<br>
# ├── .env                             # Environment variables (e.g., Mongo URI)<br>
# │<br>
# ├── /config/                         # App configuration (DB, etc.)<br>
# │   └── db.js<br>
# │<br>
# ├── /public/                         # Static files (CSS, JS, Images)<br>
# │   ├── /css/<br>
# │   ├── /js/<br>
# │   └── /images/<br>
# │<br>
# ├── /routes/                         # All route handlers<br>
# │   ├── index.js                     # Home, About, Contact<br>
# │   ├── products.js                  # Product listing/detail<br>
# │   ├── auth.js                      # Register, Login, Logout<br>
# │   ├── cart.js                      # Cart & Checkout<br>
# │   ├── orders.js                    # View user orders<br>
# │   └── admin.js                     # Admin panel routes<br>
# │<br>
# ├── /controllers/                    # Controller logic (DB + render)<br>
# │   ├── authController.js<br>
# │   ├── productController.js<br>
# │   ├── cartController.js<br>
# │   ├── orderController.js<br>
# │   └── adminController.js<br>
# │<br>
# ├── /models/                         # Mongoose Models (MongoDB)<br>
# │   ├── User.js<br>
# │   ├── Product.js<br>
# │   └── Order.js<br>
# │<br>
# ├── /middleware/                     # Middleware for auth, admin, etc.<br>
# │   ├── authMiddleware.js<br>
# │   └── adminMiddleware.js<br>
# │<br>
# ├── /views/                          # EJS templates (HTML structure)<br>
# │   ├── /partials/                   # Reusable: header, footer, nav<br>
# │   │   ├── header.ejs<br>
# │   │   ├── footer.ejs<br>
# │   │   └── nav.ejs<br>
# │   │<br>
# │   ├── /auth/                       # Login/Register pages<br>
# │   │   ├── login.ejs<br>
# │   │   └── register.ejs<br>
# │   │<br>
# │   ├── /products/                   # All product-related pages<br>
# │   │   ├── list.ejs<br>
# │   │   └── detail.ejs<br>
# │   │<br>
# │   ├── /cart/                       # Cart and Checkout<br>
# │   │   ├── cart.ejs<br>
# │   │   └── checkout.ejs<br>
# │   │<br>
# │   ├── /orders/                     # User orders page<br>
# │   │   └── myOrders.ejs<br>
# │   │<br>
# │   ├── /admin/                      # Admin pages (CRUD + Orders)<br>
# │   │   ├── dashboard.ejs<br>
# │   │   ├── addProduct.ejs<br>
# │   │   ├── editProduct.ejs<br>
# │   │   └── viewOrders.ejs<br>
# │   │<br>
# │   └── index.ejs                    # Home (Landing) page<br>
# │<br>
# ├── /cv/                             # Static CV created with HTML/CSS<br>
# │   ├── index.html<br>
# │   └── style.css<br>
# <br>
# ```
# ```
